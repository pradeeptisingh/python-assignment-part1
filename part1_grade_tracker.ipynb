# %% [markdown]
#  **STUDENT GRADE TRACKER**

# %% [markdown]
# Task 1: Data Parsing & Profile Cleaning

# %%
# Raw student data containing inconsistent formatting
raw_students = [
    {"name": "  ayesha SHARMA  ", "roll": "101", "marks_str": "88, 72, 95, 60, 78"},
    {"name": "ROHIT verma",       "roll": "102", "marks_str": "55, 68, 49, 72, 61"},
    {"name": "  Priya Nair  ",    "roll": "103", "marks_str": "91, 85, 88, 94, 79"},
    {"name": "karan MEHTA",       "roll": "104", "marks_str": "40, 55, 38, 62, 50"},
    {"name": " Sneha pillai ",    "roll": "105", "marks_str": "75, 80, 70, 68, 85"},
]

# List to store cleaned and processed student data
cleaned_students = []

# Loop through each student record
for student in raw_students:

  # Clean name: remove extra spaces and convert to proper title case
  name = student["name"].strip().title()

  # Convert roll no. to integer
  roll = int(student["roll"])

  # Convert marks string to list of integers
  marks = list(map(int, student["marks_str"].split(", ")))

  # validate name (only alphabets)
  is_valid = all(word.isalpha() for word in name.split())
  if is_valid:
        print(f"{name} → ✓ Valid name")
  else:
        print(f"{name} → ✗ Invalid name")

  # store cleaned data
  cleaned_students.append({
        "name": name,
        "roll": roll,
        "marks": marks
    })

  # print profile card
  print("================================")
  print(f"Student : {name}")
  print(f"Roll No : {roll}")
  print(f"Marks   : {marks}")
  print("================================")

 # print roll 103 in caps & lowercase
for s in cleaned_students:
    if s["roll"] == 103:
        print("ALL CAPS :", s["name"].upper())
        print("lowercase:", s["name"].lower())
# Out:
# Ayesha Sharma → ✓ Valid name
# ...
# Student : Ayesha Sharma
# Roll No : 101
# Marks   : [88, 72, 95, 60, 78]
# ...
# Rohit Verma → ✓ Valid name
# ...
# Student : Rohit Verma
# Roll No : 102
# Marks   : [55, 68, 49, 72, 61]
# ...
# Priya Nair → ✓ Valid name
# ...
# Student : Priya Nair
# Roll No : 103
# Marks   : [91, 85, 88, 94, 79]
# ...
# Karan Mehta → ✓ Valid name
# ...
# Student : Karan Mehta
# Roll No : 104
# Marks   : [40, 55, 38, 62, 50]
# ...
# Sneha Pillai → ✓ Valid name
# ...
# Student : Sneha Pillai
# Roll No : 105
# Marks   : [75, 80, 70, 68, 85]
# ...
# ALL CAPS : PRIYA NAIR
# lowercase: priya nair

# %% [markdown]
# Task 2: Marks Analysis Using Loops & Conditionals

# %%
student_name = "Ayesha Sharma"
subjects = ["Math", "Physics", "CS", "English", "Chemistry"]
marks = [88, 72, 95, 60, 78]

print("\n--- Subject-wise Grades ---")

# Loop through subjects and marks together using zip()
for sub, m in zip(subjects, marks):

# Assign grades based on marks
    if m >= 90:
        grade = "A+"
    elif m >= 80:
        grade = "A"
    elif m >= 70:
        grade = "B"
    elif m >= 60:
        grade = "C"
    else:
        grade = "F"

    print(f"{sub}: {m} → {grade}")

    # ------------------ Calculations ------------------
total = sum(marks)
average = round(total / len(marks), 2)

print("\nTotal Marks:", total)
print("Average:", average)

# ------------------ Highest & Lowest ------------------
max_marks = max(marks)
min_marks = min(marks)

print("Highest:", subjects[marks.index(max_marks)], max_marks)
print("Lowest :", subjects[marks.index(min_marks)], min_marks)

# ------------------ Marks Entry System ------------------

# Lists to store newly added subjects and marks
new_subjects = []
new_marks = []

while True:
    subject = input("Enter subject (or 'done' to stop): ")

    if subject.lower() == "done":
        break
    try:
        mark = int(input("Enter marks (0-100): "))

        if 0 <= mark <= 100:
            new_subjects.append(subject)
            new_marks.append(mark)
        else:
            print("⚠ Marks must be between 0 and 100")

    except:
        print("⚠ Invalid input, enter numeric value")


# ------------------ Final Results ------------------
print("\nNew subjects added:", len(new_subjects))

all_marks = marks + new_marks
updated_avg = round(sum(all_marks) / len(all_marks), 2)

print("Updated Average:", updated_avg)
# Out:
# --- Subject-wise Grades ---
# Math: 88 → A
# Physics: 72 → B
# CS: 95 → A+
# English: 60 → C
# Chemistry: 78 → B
#
# Total Marks: 393
# Average: 78.6
# Highest: CS 95
# Lowest : English 60
# Enter subject (or 'done' to stop): 63
# Enter marks (0-100): 46
# Enter subject (or 'done' to stop): done
#
# New subjects added: 1
# Updated Average: 73.17

# %% [markdown]
# Task 3: Class Perfomance Summary

# %%
# Class data: each student has a name and a list of marks
class_data = [
    ("Ayesha Sharma",  [88, 72, 95, 60, 78]),
    ("Rohit Verma",    [55, 68, 49, 72, 61]),
    ("Priya Nair",     [91, 85, 88, 94, 79]),
    ("Karan Mehta",    [40, 55, 38, 62, 50]),
    ("Sneha Pillai",   [75, 80, 70, 68, 85]),
]

# Print table header
print("\nName              | Average | Status")
print("----------------------------------------")

# Initialize counters and variables
pass_count = 0
fail_count = 0
topper = ("", 0)

total_avg_sum = 0

# Loop through each student record
for name, marks in class_data:

    avg = round(sum(marks) / len(marks), 2)
    total_avg_sum += avg

    status = "Pass" if avg >= 60 else "Fail"

    if status == "Pass":
        pass_count += 1
    else:
        fail_count += 1

        if avg > topper[1]:
         topper = (name, avg)

    print(f"{name:<18} | {avg:>6}  | {status}")

# ------------------ Final Results ------------------

print("\nPassed:", pass_count)
print("Failed:", fail_count)
print("Topper:", topper[0], topper[1])
print("Class Average:", round(total_avg_sum / len(class_data), 2))
# Out:
# Name              | Average | Status
# ----------------------------------------
# Ayesha Sharma      |   78.6  | Pass
# Rohit Verma        |   61.0  | Pass
# Priya Nair         |   87.4  | Pass
# Karan Mehta        |   49.0  | Fail
# Sneha Pillai       |   75.6  | Pass
#
# Passed: 4
# Failed: 1
# Topper: Karan Mehta 49.0
# Class Average: 70.32

# %% [markdown]
# Task 4: String Manipulation Utility

# %%
essay = "  python is a versatile language. it supports object oriented, functional, and procedural programming. python is widely used in data science and machine learning.  "

# step 1
clean_essay = essay.strip()
print("\nClean Essay:", clean_essay)

# step 2
print("\nTitle Case:\n", clean_essay.title())

# step 3
count = clean_essay.count("python")
print("\n'python' count:", count)

# step 4
replaced = clean_essay.replace("python", "Python 🐍")
print("\nReplaced:\n", replaced)

# step 5
sentences = clean_essay.split(". ")
print("\nSentence List:", sentences)

# step 6
print("\nNumbered Sentences:")
for i, s in enumerate(sentences, 1):
    if not s.endswith("."):
        s += "."
    print(f"{i}. {s}")
# Out:
# Clean Essay: python is a versatile language. it supports object oriented, functional, and procedural programming. python is widely used in data science and machine learning.
#
# Title Case:
#  Python Is A Versatile Language. It Supports Object Oriented, Functional, And Procedural Programming. Python Is Widely Used In Data Science And Machine Learning.
#
# 'python' count: 2
#
# Replaced:
#  Python 🐍 is a versatile language. it supports object oriented, functional, and procedural programming. Python 🐍 is widely used in data science and machine learning.
#
# Sentence List: ['python is a versatile language', 'it supports object oriented, functional, and procedural programming', 'python is widely used in data science and machine learning.']
#
# Numbered Sentences:
# 1. python is a versatile language.
# 2. it supports object oriented, functional, and procedural programming.
# 3. python is widely used in data science and machine learning.
